# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **SpaceX  Falcon 9 first stage Landing Prediction**

# %% [markdown]
# # Lab 1: Collecting the data

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this capstone, we will predict if the Falcon 9 first stage will land successfully. SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars; other providers cost upward of 165 million dollars each, much of the savings is because SpaceX can reuse the first stage. Therefore if we can determine if the first stage will land, we can determine the cost of a launch. This information can be used if an alternate company wants to bid against SpaceX for a rocket launch. In this lab, you will collect and make sure the data is in the correct format from an API. The following is an example of a successful and launch.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/lab_v2/images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/lab_v2/images/crash.gif)

# %% [markdown]
# Most unsuccessful landings are planned. Space X performs a controlled landing in the oceans.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will make a get request to the SpaceX API. You will also do some basic data wrangling and formating.
#
# - Request to the SpaceX API
# - Clean the requested data

# %% [markdown]
# ----

# %% [markdown]
# ## Import Libraries and Define Auxiliary Functions

# %% [markdown]
# We will import the following libraries into the lab

# %%
# Requests allows us to make HTTP requests which we will use to get data from an API
import requests
# Pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
# NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np
# Datetime is a library that allows us to represent dates
import datetime

# Setting this option will print all collumns of a dataframe
pd.set_option('display.max_columns', None)
# Setting this option will print all of the data in a feature
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Below we will define a series of helper functions that will help us use the API to extract information using identification numbers in the launch data.
#
# From the <code>rocket</code> column we would like to learn the booster name.

# %%
# Takes the dataset and uses the rocket column to call the API and append the data to the list
def getBoosterVersion(data):
    for x in data['rocket']:
        if x:
            response = requests.get("https://api.spacexdata.com/v4/rockets/"+str(x)).json()
            BoosterVersion.append(response['name'])

# %% [markdown]
# From the <code>launchpad</code> we would like to know the name of the launch site being used, the logitude, and the latitude.

# %%
# Takes the dataset and uses the launchpad column to call the API and append the data to the list
def getLaunchSite(data):
    for x in data['launchpad']:
        if x:
            response = requests.get("https://api.spacexdata.com/v4/launchpads/"+str(x)).json()
            Longitude.append(response['longitude'])
            Latitude.append(response['latitude'])
            LaunchSite.append(response['name'])

# %% [markdown]
# From the <code>payload</code> we would like to learn the mass of the payload and the orbit that it is going to.

# %%
# Takes the dataset and uses the payloads column to call the API and append the data to the lists
def getPayloadData(data):
    for load in data['payloads']:
        if load:
            response = requests.get("https://api.spacexdata.com/v4/payloads/"+load).json()
            PayloadMass.append(response['mass_kg'])
            Orbit.append(response['orbit'])

# %% [markdown]
# From <code>cores</code> we would like to learn the outcome of the landing, the type of the landing, number of flights with that core, whether gridfins were used, wheter the core is reused, wheter legs were used, the landing pad used, the block of the core which is a number used to seperate version of cores, the number of times this specific core has been reused, and the serial of the core.

# %%
# Takes the dataset and uses the cores column to call the API and append the data to the lists
def getCoreData(data):
    for core in data['cores']:
        if core['core'] is not None:
            response = requests.get("https://api.spacexdata.com/v4/cores/"+core['core']).json()
            Block.append(response['block'])
            ReusedCount.append(response['reuse_count'])
            Serial.append(response['serial'])
        else:
            Block.append(None)
            ReusedCount.append(None)
            Serial.append(None)
            Outcome.append(str(core['landing_success'])+' '+str(core['landing_type']))
            Flights.append(core['flight'])
            GridFins.append(core['gridfins'])
            Reused.append(core['reused'])
            Legs.append(core['legs'])
            LandingPad.append(core['landpad'])

# %% [markdown]
# Now let's start requesting rocket launch data from SpaceX API with the following URL:

# %%
spacex_url="https://api.spacexdata.com/v4/launches/past"

# %%
response = requests.get(spacex_url)

# %% [markdown]
# Check the content of the response

# %%
#print(response.content)

# %% [markdown]
# You should see the response contains massive information about SpaceX launches. Next, let's try to discover some more relevant information for this project.

# %% [markdown]
# ### Task 1: Request and parse the SpaceX launch data using the GET request

# %% [markdown]
# To make the requested JSON results more consistent, we will use the following static response object for this project:

# %%
static_json_url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/API_call_spacex_api.json'

# %% [markdown]
# We should see that the request was successfull with the 200 status response code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# Now we decode the response content as a Json using <code>.json()</code> and turn it into a Pandas dataframe using <code>.json_normalize()</code>

# %%
# Use json_normalize meethod to convert the json result into a dataframe
data = pd.json_normalize(response.json())

# %% [markdown]
# Using the dataframe <code>data</code> print the first 5 rows

# %%
# Get the head of the dataframe
data.head()
# Out:
#        static_fire_date_utc  static_fire_date_unix    net  window  \
# 0  2006-03-17T00:00:00.000Z           1.142554e+09  False     0.0
# 1                      None                    NaN  False     0.0
# 2                      None                    NaN  False     0.0
# 3  2008-09-20T00:00:00.000Z           1.221869e+09  False     0.0
# 4                      None                    NaN  False     0.0
#
#                      rocket success  \
# 0  5e9d0d95eda69955f709d1eb   False
# 1  5e9d0d95eda69955f709d1eb   False
# 2  5e9d0d95eda69955f709d1eb   False
# 3  5e9d0d95eda69955f709d1eb    True
# 4  5e9d0d95eda69955f709d1eb    True
#
#                                                                                                             failures  \
# 0                                                [{'time': 33, 'altitude': None, 'reason': 'merlin engine failure'}]
# 1            [{'time': 301, 'altitude': 289, 'reason': 'harmonic oscillation leading to premature engine shutdown'}]
# 2  [{'time': 140, 'altitude': 35, 'reason': 'residual stage-1 thrust led to collision between stage 1 and stage 2'}]
# 3                                                                                                                 []
# 4                                                                                                                 []
#
#                                                                                                                                                                                 details  \
# 0                                                                                                                                      Engine failure at 33 seconds and loss of vehicle
# 1  Successful first stage burn and transition to second stage, maximum altitude 289 km, Premature engine shutdown at T+7 min 30 s, Failed to reach orbit, Failed to recover first stage
# 2                                                                                                                  Residual stage 1 thrust led to collision between stage 1 and stage 2
# 3                        Ratsat was carried to orbit on the first successful orbital launch of any privately funded and developed, liquid-propelled carrier rocket, the SpaceX Falcon 1
# 4                                                                                                                                                                                  None
#
#   crew ships capsules                                              payloads  \
# 0   []    []       []                            [5eb0e4b5b6c3bb0006eeb1e1]
# 1   []    []       []                            [5eb0e4b6b6c3bb0006eeb1e2]
# 2   []    []       []  [5eb0e4b6b6c3bb0006eeb1e3, 5eb0e4b6b6c3bb0006eeb1e4]
# 3   []    []       []                            [5eb0e4b7b6c3bb0006eeb1e5]
# 4   []    []       []                            [5eb0e4b7b6c3bb0006eeb1e6]
#
#                   launchpad  flight_number         name  \
# 0  5e9e4502f5090995de566f86              1    FalconSat
# 1  5e9e4502f5090995de566f86              2      DemoSat
# 2  5e9e4502f5090995de566f86              3  Trailblazer
# 3  5e9e4502f5090995de566f86              4       RatSat
# 4  5e9e4502f5090995de566f86              5     RazakSat
#
#                    date_utc   date_unix                 date_local  \
# 0  2006-03-24T22:30:00.000Z  1143239400  2006-03-25T10:30:00+12:00
# 1  2007-03-21T01:10:00.000Z  1174439400  2007-03-21T13:10:00+12:00
# 2  2008-08-03T03:34:00.000Z  1217734440  2008-08-03T15:34:00+12:00
# 3  2008-09-28T23:15:00.000Z  1222643700  2008-09-28T11:15:00+12:00
# 4  2009-07-13T03:35:00.000Z  1247456100  2009-07-13T15:35:00+12:00
#
#   date_precision  upcoming  \
# 0           hour     False
# 1           hour     False
# 2           hour     False
# 3           hour     False
# 4           hour     False
#
#                                                                                                                                                                                               cores  \
# 0  [{'core': '5e9e289df35918033d3b2623', 'flight': 1, 'gridfins': False, 'legs': False, 'reused': False, 'landing_attempt': False, 'landing_success': None, 'landing_type': None, 'landpad': None}]
# 1  [{'core': '5e9e289ef35918416a3b2624', 'flight': 1, 'gridfins': False, 'legs': False, 'reused': False, 'landing_attempt': False, 'landing_success': None, 'landing_type': None, 'landpad': None}]
# 2  [{'core': '5e9e289ef3591814873b2625', 'flight': 1, 'gridfins': False, 'legs': False, 'reused': False, 'landing_attempt': False, 'landing_success': None, 'landing_type': None, 'landpad': None}]
# 3  [{'core': '5e9e289ef3591855dc3b2626', 'flight': 1, 'gridfins': False, 'legs': False, 'reused': False, 'landing_attempt': False, 'landing_success': None, 'landing_type': None, 'landpad': None}]
# 4  [{'core': '5e9e289ef359184f103b2627', 'flight': 1, 'gridfins': False, 'legs': False, 'reused': False, 'landing_attempt': False, 'landing_success': None, 'landing_type': None, 'landpad': None}]
#
#    auto_update    tbd launch_library_id                        id  \
# 0         True  False              None  5eb87cd9ffd86e000604b32a
# 1         True  False              None  5eb87cdaffd86e000604b32b
# 2         True  False              None  5eb87cdbffd86e000604b32c
# 3         True  False              None  5eb87cdbffd86e000604b32d
# 4         True  False              None  5eb87cdcffd86e000604b32e
#
#   fairings.reused fairings.recovery_attempt fairings.recovered fairings.ships  \
# 0           False                     False              False             []
# 1           False                     False              False             []
# 2           False                     False              False             []
# 3           False                     False              False             []
# 4           False                     False              False             []
#
#                                  links.patch.small  \
# 0  https://images2.imgbox.com/94/f2/NN6Ph45r_o.png
# 1  https://images2.imgbox.com/f9/4a/ZboXReNb_o.png
# 2  https://images2.imgbox.com/6c/cb/na1tzhHs_o.png
# 3  https://images2.imgbox.com/95/39/sRqN7rsv_o.png
# 4  https://images2.imgbox.com/ab/5a/Pequxd5d_o.png
#
#                                  links.patch.large links.reddit.campaign  \
# 0  https://images2.imgbox.com/5b/02/QcxHUb5V_o.png                  None
# 1  https://images2.imgbox.com/80/a2/bkWotCIS_o.png                  None
# 2  https://images2.imgbox.com/4a/80/k1oAkY0k_o.png                  None
# 3  https://images2.imgbox.com/a3/99/qswRYzE8_o.png                  None
# 4  https://images2.imgbox.com/92/e4/7Cf6MLY0_o.png                  None
#
#   links.reddit.launch links.reddit.media links.reddit.recovery  \
# 0                None               None                  None
# 1                None               None                  None
# 2                None               None                  None
# 3                None               None                  None
# 4                None               None                  None
#
#   links.flickr.small links.flickr.original  \
# 0                 []                    []
# 1                 []                    []
# 2                 []                    []
# 3                 []                    []
# 4                 []                    []
#
#                                                                                            links.presskit  \
# 0                                                                                                    None
# 1                                                                                                    None
# 2                                                                                                    None
# 3                                                                                                    None
# 4  http://www.spacex.com/press/2012/12/19/spacexs-falcon-1-successfully-delivers-razaksat-satellite-orbit
#
#                                  links.webcast links.youtube_id  \
# 0  https://www.youtube.com/watch?v=0a_00nJ_Y88      0a_00nJ_Y88
# 1  https://www.youtube.com/watch?v=Lk4zQ2wP-Nc      Lk4zQ2wP-Nc
# 2  https://www.youtube.com/watch?v=v0w9p3U8860      v0w9p3U8860
# 3  https://www.youtube.com/watch?v=dLQ2tZEH6G0      dLQ2tZEH6G0
# 4  https://www.youtube.com/watch?v=yTaIDooc8Og      yTaIDooc8Og
#
#                                                                   links.article  \
# 0  https://www.space.com/2196-spacex-inaugural-falcon-1-rocket-lost-launch.html
# 1      https://www.space.com/3590-spacex-falcon-1-rocket-fails-reach-orbit.html
# 2       http://www.spacex.com/news/2013/02/11/falcon-1-flight-3-mission-summary
# 3                                          https://en.wikipedia.org/wiki/Ratsat
# 4                       http://www.spacex.com/news/2013/02/12/falcon-1-flight-5
#
#                                          links.wikipedia  fairings
# 0                  https://en.wikipedia.org/wiki/DemoSat       NaN
# 1                  https://en.wikipedia.org/wiki/DemoSat       NaN
# 2  https://en.wikipedia.org/wiki/Trailblazer_(satellite)       NaN
# 3                   https://en.wikipedia.org/wiki/Ratsat       NaN
# 4                 https://en.wikipedia.org/wiki/RazakSAT       NaN

# %% [markdown]
# You will notice that a lot of the data are IDs. For example the rocket column has no information about the rocket just an identification number.
#
# We will now use the API again to get information about the launches using the IDs given for each launch. Specifically we will be using columns <code>rocket</code>, <code>payloads</code>, <code>launchpad</code>, and <code>cores</code>.

# %%
# Lets take a subset of our dataframe keeping only the features we want and the flight number, and date_utc.
data = data[['rocket', 'payloads', 'launchpad', 'cores', 'flight_number', 'date_utc']]

# We will remove rows with multiple cores because those are falcon rockets with 2 extra rocket boosters and rows that have multiple payloads in a single rocket.
data = data[data['cores'].map(len) == 1]
data = data[data['payloads'].map(len) == 1]

# Since payloads and cores are lists of size 1 we will also extract the single value in the list and replace the feature.
data['cores'] = data['cores'].map(lambda x: x[0])
data['payloads'] = data['payloads'].map(lambda x: x[0])

# We also want to convert the date_utc to a datetime datatype and then extracting the date leaving the time
data['date'] = pd.to_datetime(data['date_utc']).dt.date

# Using the date we will restrict the dates of the launches
data = data[data['date'] <= datetime.date(2020, 11, 13)]

# %% [markdown]
# * From the <code>rocket</code> we would like to learn the booster name
#
# * From the <code>payload</code> we would like to learn the mass of the payload and the orbit that it is going to
#
# * From the <code>launchpad</code> we would like to know the name of the launch site being used, the longitude, and the latitude.
#
# * **From <code>cores</code> we would like to learn the outcome of the landing, the type of the landing, number of flights with that core, whether gridfins were used, whether the core is reused, whether legs were used, the landing pad used, the block of the core which is a number used to seperate version of cores, the number of times this specific core has been reused, and the serial of the core.**
#
# The data from these requests will be stored in lists and will be used to create a new dataframe.

# %%
#Global variables 
BoosterVersion = []
PayloadMass = []
Orbit = []
LaunchSite = []
Outcome = []
Flights = []
GridFins = []
Reused = []
Legs = []
LandingPad = []
Block = []
ReusedCount = []
Serial = []
Longitude = []
Latitude = []

# %% [markdown]
# These functions will apply the outputs globally to the above variables. Let's take a looks at <code>BoosterVersion</code> variable. Before we apply  <code>getBoosterVersion</code> the list is empty:

# %%
BoosterVersion
# Out:
# []

# %% [markdown]
# Now, let's apply <code> getBoosterVersion</code> function method to get the booster version

# %%
# Call getBoosterVersion
getBoosterVersion(data)

# %% [markdown]
# the list has now been update

# %%
BoosterVersion[0:5]
# Out:
# ['Falcon 1', 'Falcon 1', 'Falcon 1', 'Falcon 1', 'Falcon 9']

# %% [markdown]
# we can apply the rest of the  functions here:

# %%
# Call getLaunchSite
getLaunchSite(data)

# %%
# Call getPayloadData
getPayloadData(data)

# %%
# Call getCoreData
getCoreData(data)

# %% [markdown]
# Finally lets construct our dataset using the data we have obtained. We we combine the columns into a dictionary.

# %%
launch_dict = \
    {'FlightNumber': list(data['flight_number']),
        'Date': list(data['date']),
        'BoosterVersion': BoosterVersion,
        'PayloadMass': PayloadMass,
        'Orbit': Orbit,
        'LaunchSite': LaunchSite,
        'Outcome': Outcome,
        'Flights': Flights,
        'GridFins': GridFins,
        'Reused': Reused,
        'Legs': Legs,
        'LandingPad': LandingPad,
        'Block': Block,
        'ReusedCount': ReusedCount,
        'Serial': Serial,
        'Longitude': Longitude,
        'Latitude': Latitude}

# %% [markdown]
# Then, we need to create a Pandas data frame from the dictionary launch_dict.

# %%
# Create a data from launch_dict
pd.DataFrame.from_dict(launch_dict, orient='index')
# Out:
#                              0                1                2   \
# FlightNumber                  1                2                4
# Date                 2006-03-24       2007-03-21       2008-09-28
# BoosterVersion         Falcon 1         Falcon 1         Falcon 1
# PayloadMass                  20             None              165
# Orbit                       LEO              LEO              LEO
# LaunchSite      Kwajalein Atoll  Kwajalein Atoll  Kwajalein Atoll
# Outcome                    None             None             None
# Flights                    None             None             None
# GridFins                   None             None             None
# Reused                     None             None             None
# Legs                       None             None             None
# LandingPad                 None             None             None
# Block                      None             None             None
# ReusedCount                   0                0                0
# Serial                 Merlin1A         Merlin2A         Merlin2C
# Longitude               167.743          167.743          167.743
# Latitude                9.04772          9.04772          9.04772
#
#                              3             4             5             6   \
# FlightNumber                  5             6             8            10
# Date                 2009-07-13    2010-06-04    2012-05-22    2013-03-01
# BoosterVersion         Falcon 1      Falcon 9      Falcon 9      Falcon 9
# PayloadMass                 200          None           525           677
# Orbit                       LEO           LEO           LEO           ISS
# LaunchSite      Kwajalein Atoll  CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40
# Outcome                    None          None          None          None
# Flights                    None          None          None          None
# GridFins                   None          None          None          None
# Reused                     None          None          None          None
# Legs                       None          None          None          None
# LandingPad                 None          None          None          None
# Block                      None             1             1             1
# ReusedCount                   0             0             0             0
# Serial                 Merlin3C         B0003         B0005         B0007
# Longitude               167.743      -80.5774      -80.5774      -80.5774
# Latitude                9.04772       28.5619       28.5619       28.5619
#
#                          7             8             9             10  \
# FlightNumber             11            12            13            14
# Date             2013-09-29    2013-12-03    2014-01-06    2014-04-18
# BoosterVersion     Falcon 9      Falcon 9      Falcon 9      Falcon 9
# PayloadMass             500          3170          3325          2296
# Orbit                    PO           GTO           GTO           ISS
# LaunchSite      VAFB SLC 4E  CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40
# Outcome                None          None          None          None
# Flights                None          None          None          None
# GridFins               None          None          None          None
# Reused                 None          None          None          None
# Legs                   None          None          None          None
# LandingPad             None          None          None          None
# Block                     1             1             1             1
# ReusedCount               0             0             0             0
# Serial                B1003         B1004         B1005         B1006
# Longitude          -120.611      -80.5774      -80.5774      -80.5774
# Latitude            34.6321       28.5619       28.5619       28.5619
#
#                           11            12            13            14  \
# FlightNumber              15            16            17            18
# Date              2014-07-14    2014-08-05    2014-09-07    2014-09-21
# BoosterVersion      Falcon 9      Falcon 9      Falcon 9      Falcon 9
# PayloadMass             1316          4535          4428          2216
# Orbit                    LEO           GTO           GTO           ISS
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40
# Outcome                 None          None          None          None
# Flights                 None          None          None          None
# GridFins                None          None          None          None
# Reused                  None          None          None          None
# Legs                    None          None          None          None
# LandingPad              None          None          None          None
# Block                      1             1             1             1
# ReusedCount                0             0             0             0
# Serial                 B1007         B1008         B1011         B1010
# Longitude           -80.5774      -80.5774      -80.5774      -80.5774
# Latitude             28.5619       28.5619       28.5619       28.5619
#
#                           15            16            17            18  \
# FlightNumber              19            20            22            23
# Date              2015-01-10    2015-02-11    2015-04-14    2015-04-27
# BoosterVersion      Falcon 9      Falcon 9      Falcon 9      Falcon 9
# PayloadMass             2395           570          1898          4707
# Orbit                    ISS         ES-L1           ISS           GTO
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40
# Outcome                 None          None          None          None
# Flights                 None          None          None          None
# GridFins                None          None          None          None
# Reused                  None          None          None          None
# Legs                    None          None          None          None
# LandingPad              None          None          None          None
# Block                      1             1             1             1
# ReusedCount                0             0             0             0
# Serial                 B1012         B1013         B1015         B1016
# Longitude           -80.5774      -80.5774      -80.5774      -80.5774
# Latitude             28.5619       28.5619       28.5619       28.5619
#
#                           19            20           21            22  \
# FlightNumber              24            25           26            27
# Date              2015-06-28    2015-12-22   2016-01-17    2016-03-04
# BoosterVersion      Falcon 9      Falcon 9     Falcon 9      Falcon 9
# PayloadMass             2477          2034          553          5271
# Orbit                    ISS           LEO           PO           GTO
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  VAFB SLC 4E  CCSFS SLC 40
# Outcome                 None          None         None          None
# Flights                 None          None         None          None
# GridFins                None          None         None          None
# Reused                  None          None         None          None
# Legs                    None          None         None          None
# LandingPad              None          None         None          None
# Block                      1             1            1             1
# ReusedCount                0             0            0             0
# Serial                 B1018         B1019        B1017         B1020
# Longitude           -80.5774      -80.5774     -120.611      -80.5774
# Latitude             28.5619       28.5619      34.6321       28.5619
#
#                           23            24            25            26  \
# FlightNumber              28            29            30            32
# Date              2016-04-08    2016-05-06    2016-05-27    2016-07-18
# BoosterVersion      Falcon 9      Falcon 9      Falcon 9      Falcon 9
# PayloadMass             3136          4696          3100          2257
# Orbit                    ISS           GTO           GTO           ISS
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40
# Outcome                 None          None          None          None
# Flights                 None          None          None          None
# GridFins                None          None          None          None
# Reused                  None          None          None          None
# Legs                    None          None          None          None
# LandingPad              None          None          None          None
# Block                      2             2             2             2
# ReusedCount                1             0             1             1
# Serial                 B1021         B1022         B1023         B1025
# Longitude           -80.5774      -80.5774      -80.5774      -80.5774
# Latitude             28.5619       28.5619       28.5619       28.5619
#
#                           27            28           29          30  \
# FlightNumber              33            34           35          36
# Date              2016-08-14    2016-09-01   2017-01-14  2017-02-19
# BoosterVersion      Falcon 9      Falcon 9     Falcon 9    Falcon 9
# PayloadMass             4600          5500         9600        2490
# Orbit                    GTO           GTO           PO         ISS
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  VAFB SLC 4E  KSC LC 39A
# Outcome                 None          None         None        None
# Flights                 None          None         None        None
# GridFins                None          None         None        None
# Reused                  None          None         None        None
# Legs                    None          None         None        None
# LandingPad              None          None         None        None
# Block                      2             3            3           3
# ReusedCount                0             0            1           1
# Serial                 B1026         B1028        B1029       B1031
# Longitude           -80.5774      -80.5774     -120.611     -80.604
# Latitude             28.5619       28.5619      34.6321     28.6081
#
#                         31          32          33          34          35  \
# FlightNumber            37          38          39          40          41
# Date            2017-03-16  2017-03-30  2017-05-01  2017-05-15  2017-06-03
# BoosterVersion    Falcon 9    Falcon 9    Falcon 9    Falcon 9    Falcon 9
# PayloadMass           5600        5300        None        6070        2708
# Orbit                  GTO         GTO         LEO         GTO         ISS
# LaunchSite      KSC LC 39A  KSC LC 39A  KSC LC 39A  KSC LC 39A  KSC LC 39A
# Outcome               None        None        None        None        None
# Flights               None        None        None        None        None
# GridFins              None        None        None        None        None
# Reused                None        None        None        None        None
# Legs                  None        None        None        None        None
# LandingPad            None        None        None        None        None
# Block                    3           2           3           3           3
# ReusedCount              0           1           1           0           1
# Serial               B1030       B1021       B1032       B1034       B1035
# Longitude          -80.604     -80.604     -80.604     -80.604     -80.604
# Latitude           28.6081     28.6081     28.6081     28.6081     28.6081
#
#                         36           37          38          39           40  \
# FlightNumber            42           43          44          45           46
# Date            2017-06-23   2017-06-25  2017-07-05  2017-08-14   2017-08-24
# BoosterVersion    Falcon 9     Falcon 9    Falcon 9    Falcon 9     Falcon 9
# PayloadMass           3669         9600        6761        2910          475
# Orbit                  GTO           PO         GTO         ISS          SSO
# LaunchSite      KSC LC 39A  VAFB SLC 4E  KSC LC 39A  KSC LC 39A  VAFB SLC 4E
# Outcome               None         None        None        None         None
# Flights               None         None        None        None         None
# GridFins              None         None        None        None         None
# Reused                None         None        None        None         None
# Legs                  None         None        None        None         None
# LandingPad            None         None        None        None         None
# Block                    3            3           3           4            3
# ReusedCount              1            1           0           1            1
# Serial               B1029        B1036       B1037       B1039        B1038
# Longitude          -80.604     -120.611     -80.604     -80.604     -120.611
# Latitude           28.6081      34.6321     28.6081     28.6081      34.6321
#
#                         41           42          43          44            45  \
# FlightNumber            47           48          49          50            51
# Date            2017-09-07   2017-10-09  2017-10-11  2017-10-30    2017-12-15
# BoosterVersion    Falcon 9     Falcon 9    Falcon 9    Falcon 9      Falcon 9
# PayloadMass           4990         9600        5200        3700          2205
# Orbit                  LEO           PO         GTO         GTO           ISS
# LaunchSite      KSC LC 39A  VAFB SLC 4E  KSC LC 39A  KSC LC 39A  CCSFS SLC 40
# Outcome               None         None        None        None          None
# Flights               None         None        None        None          None
# GridFins              None         None        None        None          None
# Reused                None         None        None        None          None
# Legs                  None         None        None        None          None
# LandingPad            None         None        None        None          None
# Block                    4            4           3           4             3
# ReusedCount              1            1           1           0             1
# Serial               B1040        B1041       B1031       B1042         B1035
# Longitude          -80.604     -120.611     -80.604     -80.604      -80.5774
# Latitude           28.6081      34.6321     28.6081     28.6081       28.5619
#
#                          46            47            48            49  \
# FlightNumber             52            53            54            57
# Date             2017-12-23    2018-01-08    2018-01-31    2018-03-06
# BoosterVersion     Falcon 9      Falcon 9      Falcon 9      Falcon 9
# PayloadMass            9600          None          4230          6092
# Orbit                    PO           LEO           GTO           GTO
# LaunchSite      VAFB SLC 4E  CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40
# Outcome                None          None          None          None
# Flights                None          None          None          None
# GridFins               None          None          None          None
# Reused                 None          None          None          None
# Legs                   None          None          None          None
# LandingPad             None          None          None          None
# Block                     3             4             3             4
# ReusedCount               1             1             1             0
# Serial                B1036         B1043         B1032         B1044
# Longitude          -120.611      -80.5774      -80.5774      -80.5774
# Latitude            34.6321       28.5619       28.5619       28.5619
#
#                          50            51            52          53  \
# FlightNumber             58            59            60          61
# Date             2018-03-30    2018-04-02    2018-04-18  2018-05-11
# BoosterVersion     Falcon 9      Falcon 9      Falcon 9    Falcon 9
# PayloadMass            9600          2760           350        3750
# Orbit                    PO           ISS           HEO         GTO
# LaunchSite      VAFB SLC 4E  CCSFS SLC 40  CCSFS SLC 40  KSC LC 39A
# Outcome                None          None          None        None
# Flights                None          None          None        None
# GridFins               None          None          None        None
# Reused                 None          None          None        None
# Legs                   None          None          None        None
# LandingPad             None          None          None        None
# Block                     4             4             4           5
# ReusedCount               1             1             1           3
# Serial                B1041         B1039         B1045       B1046
# Longitude          -120.611      -80.5774      -80.5774     -80.604
# Latitude            34.6321       28.5619       28.5619     28.6081
#
#                           54            55            56           57  \
# FlightNumber              63            64            65           66
# Date              2018-06-04    2018-06-29    2018-07-22   2018-07-25
# BoosterVersion      Falcon 9      Falcon 9      Falcon 9     Falcon 9
# PayloadMass          5383.85          2410          7076         9600
# Orbit                    GTO           ISS           GTO           PO
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40  VAFB SLC 4E
# Outcome                 None          None          None         None
# Flights                 None          None          None         None
# GridFins                None          None          None         None
# Reused                  None          None          None         None
# Legs                    None          None          None         None
# LandingPad              None          None          None         None
# Block                      4             4             5            5
# ReusedCount                1             1             2            4
# Serial                 B1040         B1045         B1047        B1048
# Longitude           -80.5774      -80.5774      -80.5774     -120.611
# Latitude             28.5619       28.5619       28.5619      34.6321
#
#                           58            59           60          61  \
# FlightNumber              67            68           69          70
# Date              2018-08-07    2018-09-10   2018-10-08  2018-11-15
# BoosterVersion      Falcon 9      Falcon 9     Falcon 9    Falcon 9
# PayloadMass             5800          7060         2800        3000
# Orbit                    GTO           GTO          SSO         GTO
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  VAFB SLC 4E  KSC LC 39A
# Outcome                 None          None         None        None
# Flights                 None          None         None        None
# GridFins                None          None         None        None
# Reused                  None          None         None        None
# Legs                    None          None         None        None
# LandingPad              None          None         None        None
# Block                      5             5            5           5
# ReusedCount                3             9            4           2
# Serial                 B1046         B1049        B1048       B1047
# Longitude           -80.5774      -80.5774     -120.611     -80.604
# Latitude             28.5619       28.5619      34.6321     28.6081
#
#                          62            63            64           65  \
# FlightNumber             71            72            73           74
# Date             2018-12-03    2018-12-05    2018-12-23   2019-01-11
# BoosterVersion     Falcon 9      Falcon 9      Falcon 9     Falcon 9
# PayloadMass            4000          2573          4400         9600
# Orbit                   SSO           ISS           MEO           PO
# LaunchSite      VAFB SLC 4E  CCSFS SLC 40  CCSFS SLC 40  VAFB SLC 4E
# Outcome                None          None          None         None
# Flights                None          None          None         None
# GridFins               None          None          None         None
# Reused                 None          None          None         None
# Legs                   None          None          None         None
# LandingPad             None          None          None         None
# Block                     5             5             5            5
# ReusedCount               3             0             0            9
# Serial                B1046         B1050         B1054        B1049
# Longitude          -120.611      -80.5774      -80.5774     -120.611
# Latitude            34.6321       28.5619       28.5619      34.6321
#
#                         66            67            68           69  \
# FlightNumber            76            78            79           80
# Date            2019-03-02    2019-05-04    2019-05-24   2019-06-12
# BoosterVersion    Falcon 9      Falcon 9      Falcon 9     Falcon 9
# PayloadMass          12259          2482         13200         1425
# Orbit                  ISS           ISS          VLEO          SSO
# LaunchSite      KSC LC 39A  CCSFS SLC 40  CCSFS SLC 40  VAFB SLC 4E
# Outcome               None          None          None         None
# Flights               None          None          None         None
# GridFins              None          None          None         None
# Reused                None          None          None         None
# Legs                  None          None          None         None
# LandingPad            None          None          None         None
# Block                    5             5             5            5
# ReusedCount             12             3             9           12
# Serial               B1051         B1056         B1049        B1051
# Longitude          -80.604      -80.5774      -80.5774     -120.611
# Latitude           28.6081       28.5619       28.5619      34.6321
#
#                           70            71            72            73  \
# FlightNumber              82            83            84            85
# Date              2019-07-25    2019-08-06    2019-11-11    2019-12-05
# BoosterVersion      Falcon 9      Falcon 9      Falcon 9      Falcon 9
# PayloadMass           2227.7          6500         15600          5000
# Orbit                    ISS           GTO          VLEO           ISS
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40
# Outcome                 None          None          None          None
# Flights                 None          None          None          None
# GridFins                None          None          None          None
# Reused                  None          None          None          None
# Legs                    None          None          None          None
# LandingPad              None          None          None          None
# Block                      5             5             5             5
# ReusedCount                3             2             4             5
# Serial                 B1056         B1047         B1048         B1059
# Longitude           -80.5774      -80.5774      -80.5774      -80.5774
# Latitude             28.5619       28.5619       28.5619       28.5619
#
#                           74            75          76            77  \
# FlightNumber              86            87          88            89
# Date              2019-12-17    2020-01-07  2020-01-19    2020-01-29
# BoosterVersion      Falcon 9      Falcon 9    Falcon 9      Falcon 9
# PayloadMass             6800         15600        None         15600
# Orbit                    GTO          VLEO          SO          VLEO
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  KSC LC 39A  CCSFS SLC 40
# Outcome                 None          None        None          None
# Flights                 None          None        None          None
# GridFins                None          None        None          None
# Reused                  None          None        None          None
# Legs                    None          None        None          None
# LandingPad              None          None        None          None
# Block                      5             5           5             5
# ReusedCount                3             9           3            12
# Serial                 B1056         B1049       B1046         B1051
# Longitude           -80.5774      -80.5774     -80.604      -80.5774
# Latitude             28.5619       28.5619     28.6081       28.5619
#
#                           78            79          80          81  \
# FlightNumber              90            91          92          93
# Date              2020-02-17    2020-03-07  2020-03-18  2020-04-22
# BoosterVersion      Falcon 9      Falcon 9    Falcon 9    Falcon 9
# PayloadMass            15600          1977       15600       15600
# Orbit                   VLEO           ISS        VLEO        VLEO
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  KSC LC 39A  KSC LC 39A
# Outcome                 None          None        None        None
# Flights                 None          None        None        None
# GridFins                None          None        None        None
# Reused                  None          None        None        None
# Legs                    None          None        None        None
# LandingPad              None          None        None        None
# Block                      5             5           5           5
# ReusedCount                3             5           4          12
# Serial                 B1056         B1059       B1048       B1051
# Longitude           -80.5774      -80.5774     -80.604     -80.604
# Latitude             28.5619       28.5619     28.6081     28.6081
#
#                         82            83            84            85  \
# FlightNumber            94            95            96            97
# Date            2020-05-30    2020-06-04    2020-06-13    2020-06-30
# BoosterVersion    Falcon 9      Falcon 9      Falcon 9      Falcon 9
# PayloadMass           9525         15600         15600          3880
# Orbit                  ISS          VLEO          VLEO           MEO
# LaunchSite      KSC LC 39A  CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40
# Outcome               None          None          None          None
# Flights               None          None          None          None
# GridFins              None          None          None          None
# Reused                None          None          None          None
# Legs                  None          None          None          None
# LandingPad            None          None          None          None
# Block                    5             5             5             5
# ReusedCount             13             9             5            12
# Serial               B1058         B1049         B1059         B1060
# Longitude          -80.604      -80.5774      -80.5774      -80.5774
# Latitude           28.6081       28.5619       28.5619       28.5619
#
#                           86            87            88          89  \
# FlightNumber              98           100           101         102
# Date              2020-07-20    2020-08-18    2020-08-30  2020-09-03
# BoosterVersion      Falcon 9      Falcon 9      Falcon 9    Falcon 9
# PayloadMass             None         15600          1600       15600
# Orbit                    GEO          VLEO           SSO        VLEO
# LaunchSite      CCSFS SLC 40  CCSFS SLC 40  CCSFS SLC 40  KSC LC 39A
# Outcome                 None          None          None        None
# Flights                 None          None          None        None
# GridFins                None          None          None        None
# Reused                  None          None          None        None
# Legs                    None          None          None        None
# LandingPad              None          None          None        None
# Block                      5             5             5           5
# ReusedCount               13             9             5          12
# Serial                 B1058         B1049         B1059       B1060
# Longitude           -80.5774      -80.5774      -80.5774     -80.604
# Latitude             28.5619       28.5619       28.5619     28.6081
#
#                         90          91            92            93
# FlightNumber           103         104           105           106
# Date            2020-10-06  2020-10-18    2020-10-24    2020-11-05
# BoosterVersion    Falcon 9    Falcon 9      Falcon 9      Falcon 9
# PayloadMass          15600       15600         15600          3681
# Orbit                 VLEO        VLEO          VLEO           MEO
# LaunchSite      KSC LC 39A  KSC LC 39A  CCSFS SLC 40  CCSFS SLC 40
# Outcome               None        None          None          None
# Flights               None        None          None          None
# GridFins              None        None          None          None
# Reused                None        None          None          None
# Legs                  None        None          None          None
# LandingPad            None        None          None          None
# Block                    5           5             5             5
# ReusedCount             13          12            12             8
# Serial               B1058       B1051         B1060         B1062
# Longitude          -80.604     -80.604      -80.5774      -80.5774
# Latitude           28.6081     28.6081       28.5619       28.5619

# %% [markdown]
# Show the summary of the dataframe

# %%
# Show the head of the dataframe
pd.DataFrame.from_dict(launch_dict, orient='index').transpose().head()
# Out:
#   FlightNumber        Date BoosterVersion PayloadMass Orbit       LaunchSite  \
# 0            1  2006-03-24       Falcon 1          20   LEO  Kwajalein Atoll
# 1            2  2007-03-21       Falcon 1        None   LEO  Kwajalein Atoll
# 2            4  2008-09-28       Falcon 1         165   LEO  Kwajalein Atoll
# 3            5  2009-07-13       Falcon 1         200   LEO  Kwajalein Atoll
# 4            6  2010-06-04       Falcon 9        None   LEO     CCSFS SLC 40
#
#   Outcome Flights GridFins Reused  Legs LandingPad Block ReusedCount  \
# 0    None    None     None   None  None       None  None           0
# 1    None    None     None   None  None       None  None           0
# 2    None    None     None   None  None       None  None           0
# 3    None    None     None   None  None       None  None           0
# 4    None    None     None   None  None       None     1           0
#
#      Serial Longitude Latitude
# 0  Merlin1A   167.743  9.04772
# 1  Merlin2A   167.743  9.04772
# 2  Merlin2C   167.743  9.04772
# 3  Merlin3C   167.743  9.04772
# 4     B0003  -80.5774  28.5619

# %% [markdown]
# ### Task 2: Filter the dataframe to only include `Falcon 9` launches

# %% [markdown]
# Finally we will remove the Falcon 1 launches keeping only the Falcon 9 launches. Filter the data dataframe using the <code>BoosterVersion</code> column to only keep the Falcon 9 launches. Save the filtered data to a new dataframe called <code>data_falcon9</code>.

# %%
# Hint data['BoosterVersion']!='Falcon 1'
datatemp = pd.DataFrame.from_dict(launch_dict, orient='index').transpose()
data_falcon9 = datatemp[datatemp['BoosterVersion'] != 'Falcon 1']

# %% [markdown]
# Now that we have removed some values we should reset the FlgihtNumber column

# %%
data_falcon9.loc[:,'FlightNumber'] = list(range(1, data_falcon9.shape[0]+1))
data_falcon9
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#     FlightNumber        Date BoosterVersion PayloadMass Orbit    LaunchSite  \
# 4              1  2010-06-04       Falcon 9        None   LEO  CCSFS SLC 40
# 5              2  2012-05-22       Falcon 9         525   LEO  CCSFS SLC 40
# 6              3  2013-03-01       Falcon 9         677   ISS  CCSFS SLC 40
# 7              4  2013-09-29       Falcon 9         500    PO   VAFB SLC 4E
# 8              5  2013-12-03       Falcon 9        3170   GTO  CCSFS SLC 40
# ..           ...         ...            ...         ...   ...           ...
# 89            86  2020-09-03       Falcon 9       15600  VLEO    KSC LC 39A
# 90            87  2020-10-06       Falcon 9       15600  VLEO    KSC LC 39A
# 91            88  2020-10-18       Falcon 9       15600  VLEO    KSC LC 39A
# 92            89  2020-10-24       Falcon 9       15600  VLEO  CCSFS SLC 40
# 93            90  2020-11-05       Falcon 9        3681   MEO  CCSFS SLC 40
#
#    Outcome Flights GridFins Reused  Legs LandingPad Block ReusedCount Serial  \
# 4     None    None     None   None  None       None     1           0  B0003
# 5     None    None     None   None  None       None     1           0  B0005
# 6     None    None     None   None  None       None     1           0  B0007
# 7     None    None     None   None  None       None     1           0  B1003
# 8     None    None     None   None  None       None     1           0  B1004
# ..     ...     ...      ...    ...   ...        ...   ...         ...    ...
# 89    None    None     None   None  None       None     5          12  B1060
# 90    None    None     None   None  None       None     5          13  B1058
# 91    None    None     None   None  None       None     5          12  B1051
# 92    None    None     None   None  None       None     5          12  B1060
# 93    None    None     None   None  None       None     5           8  B1062
#
#    Longitude Latitude
# 4   -80.5774  28.5619
# 5   -80.5774  28.5619
# 6   -80.5774  28.5619
# 7   -120.611  34.6321
# 8   -80.5774  28.5619
# ..       ...      ...
# 89   -80.604  28.6081
# 90   -80.604  28.6081
# 91   -80.604  28.6081
# 92  -80.5774  28.5619
# 93  -80.5774  28.5619
#
# [90 rows x 17 columns]

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# We can see below that some of the rows are missing values in our dataset.

# %%
#data_falcon9.isnull('LandingPad')
data_falcon9.isnull().sum()
# Out:
# FlightNumber       0
# Date               0
# BoosterVersion     0
# PayloadMass        5
# Orbit              0
# LaunchSite         0
# Outcome           90
# Flights           90
# GridFins          90
# Reused            90
# Legs              90
# LandingPad        90
# Block              0
# ReusedCount        0
# Serial             0
# Longitude          0
# Latitude           0
# dtype: int64

# %% [markdown]
# Before we can continue we must deal with these missing values. The <code>LandingPad</code> column will retain None values to represent when landing pads were not used.

# %% [markdown]
# ### Task 3: Dealing with Missing Values

# %% [markdown]
# Calculate below the mean for the <code>PayloadMass</code> using the <code>.mean()</code>. Then use the mean and the <code>.replace()</code> function to replace `np.nan` values in the data with the mean you calculated.

# %%
# Calculate the mean value of PayloadMass column
payloadmassmean = data_falcon9["PayloadMass"].astype("float").mean(axis=0)
print(payloadmassmean)
# Replace the np.nan values with its mean value
# Out:
# 6123.547647058824

# %% [markdown]
# You should see the number of missing values of the <code>PayLoadMass</code> change to zero.

# %% [markdown]
# Now we should have no missing values in our dataset except for in <code>LandingPad</code>.

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section,but to make the answers consistent, in the next lab we will provide data in a pre-selected date range.

# %%
data_falcon9.to_csv('dataset_part_1.csv', index=False)

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2020-09-20|1.1|Joseph|get result each time you run|
# |2020-09-20|1.1|Azim |Created Part 1 Lab using SpaceX API|
# |2020-09-20|1.0|Joseph |Modified Multiple Areas|

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
